# %%
import os
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats
from scipy.stats import shapiro, kstest, pearsonr
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# %%
### 원본데이터에서 국산 차들에 대한 데이터들만 추출

#df = pd.read_csv('C:/JHY/used_cars_data.csv')
#df1 = df[df["make_name"]== "Hyundai"]
#df2 = df[df["make_name"]== "Kia"]
#df3 = pd.concat([df1,df2])
#df3 = df3.reset_index()
#df3 = df3.drop(['level_0','index','vin','description','main_picture_url','listing_id'], axis = 1)
#df3.to_csv('C:/JHY/used_cars_data_korea.csv') #csv파일로 생성

# %%
df3 = pd.read_csv('C:/JHY/used_cars_data_korea.csv')

# %%
plt.figure(figsize=(12,5))
sns.heatmap(df3.isna(),cbar=False)
# Out:
# <AxesSubplot:>

# %%
df3 = df3.drop(['bed','bed_height','bed_length','combine_fuel_economy','cabin','is_certified','vehicle_damage_category'], axis = 1)

# %%
plt.figure(figsize=(18,14))
sns.heatmap(df3.corr(), annot=True)
plt.title('Correlation between the columns', fontsize = 15)
plt.show()

# %%
data = df3.copy()
plt.figure(figsize=(15,8))
sns.countplot(data["back_legroom"].astype(str).sort_values())
plt.title("back_legroom", fontsize=30)
plt.show()

# %%
data = df3.copy()
plt.figure(figsize=(15,8))
sns.countplot(data["body_type"].astype(str).sort_values())
plt.title("body_type", fontsize=30)
plt.show()

# %%
data = df3.copy()
plt.figure(figsize=(15,8))
sns.countplot(data["city"].astype(str).sort_values())
plt.title("city", fontsize=30)
plt.show()

# %%
data = df3.copy()
plt.figure(figsize=(15,8))
sns.countplot(data["city_fuel_economy"].astype(str).sort_values())
plt.title("city_fuel_economy", fontsize=30)
plt.show()

# %%
data = df3.copy()
plt.figure(figsize=(15,8))
sns.countplot(data["daysonmarket"].astype(str).sort_values())
plt.title("daysonmarket", fontsize=30)
plt.show()

# %%
data = df3.copy()
plt.figure(figsize=(15,8))
sns.countplot(data["dealer_zip"].astype(str).sort_values())
plt.title("dealer_zip", fontsize=30)
plt.show()

# %%
data = df3.copy()
plt.figure(figsize=(15,8))
sns.countplot(data["engine_cylinders"].astype(str).sort_values())
plt.title("engine_cylinders", fontsize=30)
plt.show()

# %%
data = df3.copy()
plt.figure(figsize=(15,8))
sns.countplot(data["engine_displacement"].astype(str).sort_values())
plt.title("engine_type", fontsize=30)
plt.show()

# %%
data = df3.copy()
plt.figure(figsize=(15,8))
sns.countplot(data["engine_type"].astype(str).sort_values())
plt.title("engine_type", fontsize=30)
plt.show()

# %%
data = df3.copy()
plt.figure(figsize=(15,8))
sns.countplot(data["exterior_color"].astype(str).sort_values())
plt.title("exterior_color", fontsize=30)
plt.show()

# %%
data = df3.copy()
plt.figure(figsize=(15,8))
sns.countplot(data["fleet"].astype(str).sort_values())
plt.title("fleet", fontsize=30)
plt.show()

# %%
data = df3.copy()
plt.figure(figsize=(15,8))
sns.countplot(data["frame_damaged"].astype(str).sort_values())
plt.title("frame_damaged", fontsize=30)
plt.show()

# %%
data = df3.copy()
plt.figure(figsize=(15,8))
sns.countplot(data["franchise_dealer"].astype(str).sort_values())
plt.title("franchise_dealer", fontsize=30)
plt.show()

# %%
data = df3.copy()
plt.figure(figsize=(30,8))
sns.countplot(data["franchise_make"].astype(str).sort_values())
plt.title("franchise_make", fontsize=30)
plt.show()

# %%
data = df3.copy()
plt.figure(figsize=(15,8))
sns.countplot(data['front_legroom'].astype(str).sort_values())
plt.title("front_legroom")
plt.show()

# %%
data = df3.copy()
plt.figure(figsize=(15,8))
sns.countplot(data['fuel_tank_volume'].astype(str).sort_values())
plt.title("fuel_tank_volume")
plt.show()

# %%
data = df3.copy()
plt.figure(figsize=(15,8))
sns.countplot(data['fuel_type'].astype(str).sort_values())
plt.title("fuel_type")
plt.show()

# %%
data = df3.copy()
plt.figure(figsize=(15,8))
sns.countplot(data['has_accidents'].astype(str).sort_values())
plt.title("has_accidents")
plt.show()

# %%
data = df3.copy()
plt.figure(figsize=(15,8))
sns.countplot(data['height'].astype(str).sort_values())
plt.title("height")
plt.show()

# %%
data = df3.copy()
plt.figure(figsize=(15,8))
sns.countplot(data['highway_fuel_economy'].astype(str).sort_values())
plt.title("highway_fuel_economy")
plt.show()

# %%
data = df3.copy()
plt.figure(figsize=(15,8))
sns.countplot(data['horsepower'].astype(str).sort_values())
plt.title("horsepower")
plt.show()

# %%
data = df3.copy()
plt.figure(figsize=(15,8))
sns.countplot(data['interior_color'].astype(str).sort_values())
plt.title("interior_color")
plt.show()

# %%
data = df3.copy()
plt.figure(figsize=(15,8))
sns.countplot(data['isCab'].astype(str).sort_values())
plt.title("isCab")
plt.show()

# %%
data = df3.copy()
plt.figure(figsize=(15,8))
sns.countplot(data['is_new'].astype(str).sort_values())
plt.title("is_new")
plt.show()

# %%
data = df3.copy()
plt.figure(figsize=(15,8))
sns.countplot(data['latitude'].astype(str).sort_values())
plt.title("latitude")
plt.show()

# %%
data = df3.copy()
plt.figure(figsize=(15,8))
sns.countplot(data['length'].astype(str).sort_values())
plt.title("length")
plt.show()

# %%
data = df3.copy()
plt.figure(figsize=(15,8))
sns.countplot(data['listed_date'].astype(str).sort_values())
plt.title("listed_date")
plt.show()

# %%
data = df3.copy()
plt.figure(figsize=(15,8))
sns.countplot(data['listing_color'].astype(str).sort_values())
plt.title("listing_color")
plt.show()

# %%
data = df3.copy()
plt.figure(figsize=(15,8))
sns.countplot(data['make_name'].astype(str).sort_values())
plt.title("make_name")
plt.show()

# %%
data = df3.copy()
plt.figure(figsize=(15,8))
sns.countplot(data['maximum_seating'].astype(str).sort_values())
plt.title("maximum_seating")
plt.show()

# %%
data = df3.copy()
plt.figure(figsize=(15,8))
sns.countplot(data['model_name'].astype(str).sort_values())
plt.title("model_name")
plt.show()

# %%
data = df3.copy()
plt.figure(figsize=(15,8))
sns.countplot(data['owner_count'].astype(str).sort_values())
plt.title("owner_count")
plt.show()

# %%
data = df3.copy()
plt.figure(figsize=(15,8))
sns.countplot(data['power'].astype(str).sort_values())
plt.title("price")
plt.show()

# %%
data = df3.copy()
plt.figure(figsize=(15,8))
sns.countplot(data['salvage'].astype(str).sort_values())
plt.title("salvage")
plt.show()

# %%
data = df3.copy()
plt.figure(figsize=(15,8))
sns.countplot(data['seller_rating'].astype(str).sort_values())
plt.title("seller_rating")
plt.show()

# %%
data = df3.copy()
plt.figure(figsize=(15,8))
sns.countplot(data['theft_title'].astype(str).sort_values())
plt.title("theft_title")
plt.show()

# %%
data = df3.copy()
plt.figure(figsize=(15,8))
sns.countplot(data['torque'].astype(str).sort_values())
plt.title("torque")
plt.show()

# %%
data = df3.copy()
plt.figure(figsize=(15,8))
sns.countplot(data['transmission'].astype(str).sort_values())
plt.title("transmission")
plt.show()

# %%
data = df3.copy()
plt.figure(figsize=(15,8))
sns.countplot(data['transmission_display'].astype(str).sort_values())
plt.title("transmission_display")
plt.show()

# %%
data = df3.copy()
plt.figure(figsize=(15,8))
sns.countplot(data['trim_name'].astype(str).sort_values())
plt.title("trim_name")
plt.show()

# %%
data = df3.copy()
plt.figure(figsize=(15,8))
sns.countplot(data['wheel_system'].astype(str).sort_values())
plt.title("wheel_system")
plt.show()

# %%
data = df3.copy()
plt.figure(figsize=(15,8))
sns.countplot(data['wheel_system_display'].astype(str).sort_values())
plt.title("wheel_system_display")
plt.show()

# %%
data = df3.copy()
plt.figure(figsize=(15,8))
sns.countplot(data['wheelbase'].astype(str).sort_values())
plt.title("wheelbase")
plt.show()

# %%
data = df3.copy()
plt.figure(figsize=(15,8))
sns.countplot(data['width'].astype(str).sort_values())
plt.title("width")
plt.show()

# %%
data = df3.copy()
plt.figure(figsize=(15,8))
sns.countplot(data['year'].astype(str).sort_values())
plt.title("year")
plt.show()
